# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
likelihood = [
    -7.732544e+01,
    -7.725691e+01,
    -7.652781e+01,
    -7.589995e+01,
    -7.579887e+01,
    -7.499374e+01,
    -7.453358e+01,
    -7.450794e+01,
    -7.374001e+01,
    -7.335786e+01,
    -7.341865e+01,
    -7.266691e+01,
    -7.231442e+01
]

index = np.arange(0, 13, 1)

plt.plot(index, likelihood)
plt.ylabel('Logarithmic likelihood')
plt.savefig('likelihood.png', format='png', dpi=500)

# %%
# word error rate
hmms = [
    17.02,
    14.39,
    12.46,
    9.82,
    10.53
]

model_number = np.arange(2, 7, 1)

plt.plot(model_number, hmms)
plt.xlabel('HMMs')
plt.ylabel('Word-error rate')
plt.savefig('word_error_rate.png', format='png', dpi=500)

# %%
# gender dependent speakers

females = [15.93]
males = [10.33]
combined = [12.98]

# male model with female set
m_f = [30.86]

# female model with male set
f_m = [40.67]

# combined for mixed
combined_mixed = [36.03]
